# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Marvina Young
# - **Email:** marvinayoung18@gmail.com
# - **ID Dicoding:** marvina_young_i9Vt

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana tren rata-rata jumlah penyewaan sepeda setiap jam ?
# - Apakah ada korelasi antara suhu dan jumlah penyewaan sepeda harian ?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
from google.colab import drive
drive.mount('/content/drive')

from google.colab import files
uploaded = files.upload()

hours_df = pd.read_csv('hour.csv')
days_df = pd.read_csv('day.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      <input type="file" id="files-f6104985-1269-4088-b7fd-3f0bf72dc721" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f6104985-1269-4088-b7fd-3f0bf72dc721">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...

# %% [markdown]
# **Insight:**
# - memasukkan data hour dan day ke dalam google colab dari file lokal komputer.

# %% [markdown]
# ### Assessing Data

# %%
hours_df.info()
hours_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB
# ...

# %%
hours_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hours_df.duplicated().sum()
# Out:
# 0

# %%
days_df.info()
days_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
# ...

# %%
days_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
days_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Insight:**
# - mengecek data hour dan day secara keseluruhan, termasuk mengecek missing value dan duplikat.
# - setelah pengecekan, tidak terdapat missing value pada data hours dan days.
# - setelah pengecekan, tidak terdapat data duplikat pada data hours dan days.

# %% [markdown]
# ### Cleaning Data

# %%
datetime_columns = ["dteday"]

for column in datetime_columns:
  hours_df[column] = pd.to_datetime(hours_df[column])
  days_df[column] = pd.to_datetime(days_df[column])
hours_df.info()
days_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB
# ...

# %% [markdown]
# **Insight:**
# - melakukan data cleaning berupa mengganti tanggal dari tipe data object menjadi tipe data datetime
# - data cleaning berhasil

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
hours_group = hours_df.groupby(by="hr").cnt.mean()
hours_group
# Out:
# hr
# 0      53.898072
# 1      33.375691
# 2      22.869930
# 3      11.727403
# 4       6.352941
# 5      19.889819
# 6      76.044138
# 7     212.064649
# 8     359.011004
# 9     219.309491
# 10    173.668501
# 11    208.143054
# 12    253.315934
# 13    253.661180
# 14    240.949246
# 15    251.233196
# 16    311.983562
# 17    461.452055
# 18    425.510989
# 19    311.523352
# 20    226.030220
# 21    172.314560
# 22    131.335165
# 23     87.831044
# Name: cnt, dtype: float64

# %%
days_df.corr()
# Out:
#              instant    dteday    season        yr      mnth   holiday  \
# instant     1.000000  1.000000  0.412224  0.866025  0.496702  0.016145
# dteday      1.000000  1.000000  0.412224  0.866025  0.496702  0.016145
# season      0.412224  0.412224  1.000000 -0.001844  0.831440 -0.010537
# yr          0.866025  0.866025 -0.001844  1.000000 -0.001792  0.007954
# mnth        0.496702  0.496702  0.831440 -0.001792  1.000000  0.019191
# holiday     0.016145  0.016145 -0.010537  0.007954  0.019191  1.000000
# weekday    -0.000016 -0.000016 -0.003080 -0.005461  0.009509 -0.101960
# workingday -0.004337 -0.004337  0.012485 -0.002013 -0.005901 -0.253023
# weathersit -0.021477 -0.021477  0.019211 -0.048727  0.043528 -0.034627
# temp        0.150580  0.150580  0.334315  0.047604  0.220205 -0.028556
# atemp       0.152638  0.152638  0.342876  0.046106  0.227459 -0.032507
# hum         0.016375  0.016375  0.205445 -0.110651  0.222204 -0.015937
# ...

# %% [markdown]
# **Insight:**
# - melakukan grouping terhadap data setiap jam dengan menghitung rata-rata jumlah penyewaan sepeda dalam tiap jam
# - mencari nilai korelasi setiap kolom dari data day

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
plt.plot(hours_group.index, hours_group.values)
plt.title("Tren Rata-rata Jumlah Penyewaan Sepeda Setiap Jam")
plt.xlabel("Jam")
plt.ylabel("Jumlah")
plt.xlim(0,24)
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
sns.regplot(x=days_df["temp"], y=days_df["cnt"])
plt.title("Korelasi antara suhu dan jumlah penyewaan sepeda")
plt.show()

# %% [markdown]
# **Insight:**
# - menampilkan plot tren dari rata-rata jumlah penyewaan sepeda setiap jam
# - menampilkan korelasi antara temperatur dan jumlah penyewaan sepeda

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Dari grafik menunjukkan pengguna sepeda memuncak di jam berangkat kerja sekitar jam 8 pagi dan memuncak kembali di jam pulang kerja sekitar jam 5 sore.
# - Dari nilai korelasi menunjukkan 0.628844 lebih mendekati angka 1 dibandingkan angka 0 dan dari grafik menunjukkan kenaikan, maka disimpulkan suhu dan jumlah penyewaan sepeda memiliki korelasi positive yang cukup erat.
